# %%
import pandas as pd

# %% [markdown]
# # load datframe

# %%
df = pd.read_table("http://bit.ly/chiporders")  # by default \t seperated files

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
colname=['userid','age','gender','occupation','zip-code']

# %%
movie = pd.read_table("http://bit.ly/movieusers",sep ='|',header=None,names=colname)
movie
# Out:
#      userid  age gender     occupation zip-code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# ...

# %% [markdown]
# # Select series from panda dataframe

# %%
ufo = pd.read_table("http://bit.ly/uforeports",sep=",")
# or   pd.read_csv()   be default ',' sepe
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['City']  
# note  casesecsitive   
# other way:
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
# ufo.Colors Reported    doesn't work  even if "name" eg. "shape" i.e prebuild attribute of datafram
ufo['Colors Reported'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Colors Reported, dtype: object

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.head
# Out:
# <bound method NDFrame.head of                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %% [markdown]
# # create new series

# %%
'ab'+'cd'           # same could be done with series (string type)
# Out:
# 'abcd'

# %%
#ufo.Location = ufo.City +', '+ ufo.State # NO
ufo['Location']=ufo.City +', '+ ufo.State
ufo.Location
# Out:
# 0                      Ithaca, NY
# 1                 Willingboro, NJ
# 2                     Holyoke, CO
# 3                     Abilene, KS
# 4        New York Worlds Fair, NY
# 5                 Valley City, ND
# 6                 Crater Lake, CA
# 7                        Alma, MI
# 8                     Eklutna, AK
# 9                     Hubbard, OR
# 10                    Fontana, CA
# 11                   Waterloo, AL
# 12                     Belton, SC
# 13                     Keokuk, IA
# 14                  Ludington, MI
# 15                Forest Home, CA
# 16                Los Angeles, CA
# 17                  Hapeville, GA
# 18                     Oneida, TN
# 19                 Bering Sea, AK
# 20                   Nebraska, NE
# 21                            NaN
# 22                            NaN
# 23                  Owensboro, KY
# 24                 Wilderness, WV
# 25                  San Diego, CA
# 26                 Wilderness, WV
# ...

# %% [markdown]
# # Why do some pandas commands end with parentheses (and others don't)?

# %%
movies = pd.read_csv("http://bit.ly/imdbratings")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.describe(include='object')
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.describe(include='all')
# Out:
#         star_rating           title content_rating  genre    duration  \
# count    979.000000             979            976    979  979.000000
# unique          NaN             975             12     16         NaN
# top             NaN  Les Miserables              R  Drama         NaN
# freq            NaN               2            460    278         NaN
# mean       7.889785             NaN            NaN    NaN  120.979571
# std        0.336069             NaN            NaN    NaN   26.218010
# min        7.400000             NaN            NaN    NaN   64.000000
# 25%        7.600000             NaN            NaN    NaN  102.000000
# 50%        7.800000             NaN            NaN    NaN  117.000000
# 75%        8.100000             NaN            NaN    NaN  134.000000
# max        9.300000             NaN            NaN    NaN  242.000000
#
#                                               actors_list
# count                                                 979
# ...

# %%
movies.describe(include=['object','float64'])
# Out:
#         star_rating           title content_rating  genre  \
# count    979.000000             979            976    979
# unique          NaN             975             12     16
# top             NaN  Les Miserables              R  Drama
# freq            NaN               2            460    278
# mean       7.889785             NaN            NaN    NaN
# std        0.336069             NaN            NaN    NaN
# min        7.400000             NaN            NaN    NaN
# 25%        7.600000             NaN            NaN    NaN
# 50%        7.800000             NaN            NaN    NaN
# 75%        8.100000             NaN            NaN    NaN
# max        9.300000             NaN            NaN    NaN
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# ...

# %% [markdown]
# # How do I rename columns in a pandas DataFrame?

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.rename(columns = {'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'},inplace=True)

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
#2

ufo_cols = ['city','colors reported','shape reported','state','time']
ufo.columns=ufo_cols

# %%
ufo.columns
# Out:
# Index(['city', 'colors reported', 'shape reported', 'state', 'time'], dtype='object')

# %%
#3
ufo = pd.read_csv("http://bit.ly/uforeports",names=ufo_cols,header=0)  
# header 0 means... row 0 has existing column name

# %%
ufo.head()
# Out:
#                    city colors reported shape reported state             time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# ### SERIES.str.replace

# %%
# BEST METHOD FOR MULTIPLE COLUMNS
ufo.columns = ufo.columns.str.replace(' ','_')

# %%
ufo.head()
# Out:
#                    city colors_reported shape_reported state             time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # How do I remove columns from a pandas DataFrame?

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.drop('colors_reported',axis=1,inplace=True)  # axis is drection = 0 row    =1column

# %%
ufo.head()
# Out:
#   shape_reported             time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %%
ufo.drop(['city','state'],axis=1,inplace=True)

# %% [markdown]
# ### row remove

# %%
# axis = 0 default
ufo.drop([0,1],axis=0,inplace=True)

# %%
ufo
# Out:
#       shape_reported              time
# 2               OVAL   2/15/1931 14:00
# 3               DISK    6/1/1931 13:00
# 4              LIGHT   4/18/1933 19:00
# 5               DISK   9/15/1934 15:30
# 6             CIRCLE    6/15/1935 0:00
# 7               DISK    7/15/1936 0:00
# 8              CIGAR  10/15/1936 17:00
# 9           CYLINDER    6/15/1937 0:00
# 10             LIGHT   8/15/1937 21:00
# 11          FIREBALL    6/1/1939 20:00
# 12            SPHERE   6/30/1939 20:00
# 13              OVAL     7/7/1939 2:00
# 14              DISK    6/1/1941 13:00
# 15            CIRCLE    7/2/1941 11:30
# 16               NaN    2/25/1942 0:00
# 17               NaN    6/1/1942 22:30
# 18         RECTANGLE    7/15/1942 1:00
# 19             OTHER   4/30/1943 23:00
# 20              DISK    6/1/1943 15:00
# 21               NaN    8/15/1943 0:00
# 22             LIGHT    8/15/1943 0:00
# 23         RECTANGLE  10/15/1943 11:00
# 24              DISK    1/1/1944 10:00
# ...

# %% [markdown]
# # How do I sort a pandas DataFrame or a Series?

# %%
 movies = pd.read_csv("http://bit.ly/imdbratings")
movies.info
# Out:
# <bound method DataFrame.info of      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# ...

# %%
movies.title.sort_values()
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies.sort_values('title',ascending=False).head()
# Out:
#      star_rating             title content_rating   genre  duration  \
# 864          7.5             [Rec]              R  Horror        78
# 526          7.8              Zulu        UNRATED   Drama       138
# 615          7.7        Zombieland              R  Comedy        88
# 677          7.7            Zodiac              R   Crime       157
# 955          7.4  Zero Dark Thirty              R   Drama       157
#
#                                            actors_list
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...

# %%
#movies[movies.genre=='Thriller'].sort_values('star_rating',ascending=False)

# %% [markdown]
# ### multiple columns

# %%
movies.sort_values(['genre','star_rating'])
# Out:
#      star_rating                                            title  \
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
# 832          7.5                                          RoboCop
# 856          7.5                      Scott Pilgrim vs. the World
# 858          7.5               Sherlock Holmes: A Game of Shadows
# 871          7.5                                               X2
# 884          7.5                                       Open Range
# 885          7.5                                     Total Recall
# 896          7.5                            From Russia with Love
# 906          7.5                                           Looper
# 908          7.5                                          Bullitt
# ...

# %% [markdown]
# # How do I apply multiple filter criteria to a pandas DataFrame?

# %%
import pandas as pd
movies = pd.read_csv("http://bit.ly/imdbratings")

# %%
movies[(movies.duration >= 200) & (movies.genre=='Crime')]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %% [markdown]
# # multiple OR statement in one

# %%
movies[movies.genre.isin(['Crime','Western'])]
# Out:
#      star_rating                             title content_rating    genre  \
# 0            9.3          The Shawshank Redemption              R    Crime
# 1            9.2                     The Godfather              R    Crime
# 2            9.1            The Godfather: Part II              R    Crime
# 4            8.9                      Pulp Fiction              R    Crime
# 6            8.9    The Good, the Bad and the Ugly      NOT RATED  Western
# 21           8.7                       City of God              R    Crime
# 23           8.7                The Usual Suspects              R    Crime
# 26           8.6      Once Upon a Time in the West          PG-13  Western
# 28           8.6            Leon: The Professional              R    Crime
# 34           8.6                American History X              R    Crime
# 40           8.5                    The Green Mile              R    Crime
# ...

# %% [markdown]
# ### Keep few columns while reading Csv file

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo = pd.read_csv('http://bit.ly/uforeports',usecols=['City','State']) #  OR   usecols=[0,3]

# %%
ufo.columns
# Out:
# Index(['City', 'State'], dtype='object')

# %% [markdown]
# ### Keep few rows while reading

# %%
ufo = pd.read_csv('http://bit.ly/uforeports',nrows=3)

# %%
ufo
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# # Iterate over Series or Dataframe

# %%
# SERIES

for c in ufo.City:
    print(c)
# Out:
# Ithaca
# Willingboro
# Holyoke

# %%
# DATAFRAME
for index,row in ufo.iterrows():
    print(index, row.City, row.State)
# Out:
# 0 Ithaca NY
# 1 Willingboro NJ
# 2 Holyoke CO

# %% [markdown]
# # DROP NON-NUMERIC COLUMNS

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
import numpy as np
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %% [markdown]
# # How do I use the "axis" parameter in pandas?

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.drop('continent',axis=1).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
drinks.drop(2,axis=0)
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# ...

# %%
drinks.mean()   # axis=0 i.e scan vertically.i.e take each row
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=1)  #  Mean of 1 row.i.e.scanned horizontally
# Out:
# 0        0.000
# 1       69.975
# 2        9.925
# 3      176.850
# 4       81.225
# 5       69.975
# 6      111.825
# 7       53.700
# 8      138.850
# 9      138.675
# 10      18.325
# 11      88.825
# 12      28.500
# 13       0.000
# 14      89.575
# 15     142.850
# 16     150.375
# 17      97.950
# 18      13.025
# 19       5.850
# 20      54.950
# 21      65.400
# 22      62.100
# 23     103.300
# 24       8.650
# 25     146.825
# 26      10.825
# 27      23.575
# 28      12.250
# 29      55.000
#         ...
# 163     79.650
# 164     24.675
# 165    101.300
# 166    143.800
# 167     14.250
# 168      4.325
# 169     91.100
# 170     55.725
# 171      1.525
# 172     14.575
# 173     15.775
# 174     91.600
# 175     18.825
# 176     20.350
# 177     31.050
# 178     14.250
# 179     15.575
# 180    124.225
# 181     39.700
# 182    137.600
# 183     12.175
# 184    124.925
# 185     94.150
# 186     34.100
# 187     12.725
# 188    110.925
# 189     29.000
# 190      1.525
# ...

# %% [markdown]
# # axis=0 'index'   axis=1 'columns'

# %%
drinks.mean(axis='index')
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis='columns')
# Out:
# 0        0.000
# 1       69.975
# 2        9.925
# 3      176.850
# 4       81.225
# 5       69.975
# 6      111.825
# 7       53.700
# 8      138.850
# 9      138.675
# 10      18.325
# 11      88.825
# 12      28.500
# 13       0.000
# 14      89.575
# 15     142.850
# 16     150.375
# 17      97.950
# 18      13.025
# 19       5.850
# 20      54.950
# 21      65.400
# 22      62.100
# 23     103.300
# 24       8.650
# 25     146.825
# 26      10.825
# 27      23.575
# 28      12.250
# 29      55.000
#         ...
# 163     79.650
# 164     24.675
# 165    101.300
# 166    143.800
# 167     14.250
# 168      4.325
# 169     91.100
# 170     55.725
# 171      1.525
# 172     14.575
# 173     15.775
# 174     91.600
# 175     18.825
# 176     20.350
# 177     31.050
# 178     14.250
# 179     15.575
# 180    124.225
# 181     39.700
# 182    137.600
# 183     12.175
# 184    124.925
# 185     94.150
# 186     34.100
# 187     12.725
# 188    110.925
# 189     29.000
# 190      1.525
# ...

# %% [markdown]
# # How do I use string methods in pandas? = str

# %%
orders = pd.read_table('http://bit.ly/chiporders')

# %%
orders.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
# 5                                CHICKEN BOWL
# 6                               SIDE OF CHIPS
# 7                               STEAK BURRITO
# 8                            STEAK SOFT TACOS
# 9                               STEAK BURRITO
# 10                        CHIPS AND GUACAMOLE
# 11                       CHICKEN CRISPY TACOS
# 12                         CHICKEN SOFT TACOS
# 13                               CHICKEN BOWL
# 14                        CHIPS AND GUACAMOLE
# 15      CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 16                            CHICKEN BURRITO
# 17                            CHICKEN BURRITO
# 18                                CANNED SODA
# 19                               CHICKEN BOWL
# ...

# %% [markdown]
# ### Find Substring in column

# %%
orders[orders.item_name.str.contains('Chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# 16           8         1       Chicken Burrito
# 17           9         1       Chicken Burrito
# 19          10         1          Chicken Bowl
# 23          12         1       Chicken Burrito
# 26          13         1          Chicken Bowl
# 29          15         1       Chicken Burrito
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# 42          20         1          Chicken Bowl
# 44          20         1    Chicken Salad Bowl
# 45          21         1       Chicken Burrito
# 52          24         1       Chicken Burrito
# 63          28         1       Chicken Burrito
# 68          30         1       Chicken Burrito
# ...

# %% [markdown]
# ### chain str methods

# %%
#orders.choice_description.str.replace('[','').str.replace(']','')
orders.choice_description.str.replace('[ \[\]]','')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-RedChiliSalsa(Hot),BlackBeans,Rice,C...
# 5       FreshTomatoSalsa(Mild),Rice,Cheese,SourCream,G...
# 6                                                     NaN
# 7       TomatilloRedChiliSalsa,FajitaVegetables,BlackB...
# 8       TomatilloGreenChiliSalsa,PintoBeans,Cheese,Sou...
# 9       FreshTomatoSalsa,Rice,BlackBeans,PintoBeans,Ch...
# 10                                                    NaN
# 11      RoastedChiliCornSalsa,FajitaVegetables,Rice,Bl...
# 12      RoastedChiliCornSalsa,Rice,BlackBeans,Cheese,S...
# 13      FreshTomatoSalsa,FajitaVegetables,Rice,Cheese,...
# 14                                                    NaN
# 15                                                    NaN
# ...

# %% [markdown]
# # How do I change the data type of a pandas Series? :   .astype()

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# ### change data types during read_csv

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry',dtype={'beer_servings':float})

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# # Sign in price $

# %%
orders = pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.item_price.str.replace('$','').astype(float).mean()
# Out:
# 7.464335785374397

# %% [markdown]
# ## Store True and False as int(0) 1

# %%
orders.item_name.str.contains('Chicken').astype(int).head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: item_name, dtype: int32

# %% [markdown]
# # When should I use a "groupby" in pandas?

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent=='Africa'].groupby('country').beer_servings.mean()
# Out:
# country
# Algeria                      25
# Angola                      217
# Benin                        34
# Botswana                    173
# Burkina Faso                 25
# Burundi                      88
# Cabo Verde                  144
# Cameroon                    147
# Central African Republic     17
# Chad                         15
# Comoros                       1
# Congo                        76
# Cote d'Ivoire                37
# DR Congo                     32
# Djibouti                     15
# Egypt                         6
# Equatorial Guinea            92
# Eritrea                      18
# Ethiopia                     20
# Gabon                       347
# Gambia                        8
# Ghana                        31
# Guinea                        9
# Guinea-Bissau                28
# Kenya                        58
# Lesotho                      82
# Liberia                      19
# Libya                         0
# Madagascar                   26
# ...

# %%
 drinks.groupby('continent').beer_servings.max()
#
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['count','min','max','mean'
                                              ])
# Out:
#                count  min  max        mean
# continent
# Africa            53    0  376   61.471698
# Asia              44    0  247   37.045455
# Europe            45    0  361  193.777778
# North America     23    1  285  145.434783
# Oceania           16    0  306   89.687500
# South America     12   93  333  175.083333

# %%
drinks.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').mean().plot(kind='bar')
